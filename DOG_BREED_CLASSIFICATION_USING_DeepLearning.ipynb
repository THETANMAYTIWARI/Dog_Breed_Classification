# %% [markdown]
# Tanmay Tiwari

# %% [markdown]
# ***Importing Libraries***

# %%
import numpy as np
from glob import glob
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
human_files = np.array(glob("/gdrive/My Drive/Deep Learning Project/human_images/*/*"))
dog_files = np.array(glob("/gdrive/My Drive/Deep Learning Project/dogImages/*/*/*"))

# %%
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8356 total dog images.

# %%
face_cascade = cv2.CascadeClassifier('/gdrive/My Drive/Deep Learning Project/haarcascade_frontalface_alt.xml')

# %%
img = cv2.imread(human_files[0])
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray)
print('Number of faces detected:', len(faces))
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %%
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### Assess the Human Face Detector

# %%
from tqdm import tqdm

human_files_short = human_files[:100]
dog_files_short = dog_files[:100]

# %%
def percentageOfDetectingFaces(detector, img_paths):
    count = 0
    for img_path in img_paths:
        if detector(img_path):
            count += 1
    return count / len(img_paths) * 100

print("The percentage of the human images that include a detected, human face: {}%.".format(percentageOfDetectingFaces(face_detector, human_files_short)))
print("The percentage of the dog images that include a detected, human face: {}%.".format(percentageOfDetectingFaces(face_detector, dog_files_short)))
# Out:
# The percentage of the human images that include a detected, human face: 99.0%.
# The percentage of the dog images that include a detected, human face: 6.0%.

# %% [markdown]
# ### Detecting Dogs

# %%
import torch
import torchvision.models as models

VGG16 = models.vgg16(pretrained=True)
use_cuda = torch.cuda.is_available()
if use_cuda:
    VGG16 = VGG16.cuda()
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 261MB/s]

# %% [markdown]
# ### Making Predictions with a Pre-trained Model

# %%
from PIL import Image
import torchvision.transforms as transforms

# %%
def VGG16_predict(img_path):
  img = Image.open(img_path)
  transform = transforms.Compose([transforms.Resize(255),transforms.CenterCrop(224),transforms.ToTensor()])
  img_tensor = transform(img)
  img_tensor.unsqueeze_(0)
  if use_cuda:
    img_tensor = img_tensor.cuda()
    prediction = VGG16(img_tensor)
  if use_cuda:
     prediction = prediction.cpu()
     return prediction.data.numpy().argmax()

# %%
def dog_detector(img_path):
    index = VGG16_predict(img_path)
    return index >= 151 and index <= 268

# %%
print("The percentage of the human images that include a detected, dog face: {}%.".format(percentageOfDetectingFaces(dog_detector, human_files_short)))
print("The percentage of the dog images that include a detected, dog face: {}%.".format(percentageOfDetectingFaces(dog_detector, dog_files_short)))
# Out:
# The percentage of the human images that include a detected, dog face: 0.0%.
# The percentage of the dog images that include a detected, dog face: 95.0%.

# %% [markdown]
# ### Creating a CNN model to classify Dog Breeds

# %%
import os
from torchvision import datasets
data_dir = '/gdrive/My Drive/Deep Learning Project/dogImages'
train_dir = os.path.join(data_dir, 'train/')
valid_dir = os.path.join(data_dir, 'valid/')
test_dir = os.path.join(data_dir, 'test/')

data_transform = transforms.Compose([transforms.RandomResizedCrop(224),
                                    transforms.RandomHorizontalFlip(),
                                    transforms.RandomRotation(10),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_data = datasets.ImageFolder(train_dir, transform=data_transform)
valid_data = datasets.ImageFolder(valid_dir, transform=data_transform)
test_data = datasets.ImageFolder(test_dir, transform=data_transform)

print('Num training images: ', len(train_data))
print('Num valid images: ', len(valid_data))
print('Num test images: ', len(test_data))
# Out:
# Num training images:  6685
# Num valid images:  835
# Num test images:  836

# %%
batch_size = 20
num_workers=0

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size,num_workers=num_workers, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,num_workers=num_workers, shuffle=True)

# %% [markdown]
# ### Model Architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 28 * 28, 500)
        self.fc2 = nn.Linear(500, 133)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 28 * 28)
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

model_scratch = Net()
print(model_scratch)

if use_cuda:
    model_scratch.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=100352, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=133, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
import torch.optim as optim
criterion_scratch = nn.CrossEntropyLoss()
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### Train and Validate the Model

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
    valid_loss_min = np.Inf

    if use_cuda:
        model = model.cuda()
        criterion = criterion.cuda()

    for epoch in range(1, n_epochs+1):
        train_loss = 0.0
        valid_loss = 0.0
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            if use_cuda:
                data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.item() - train_loss))

        with torch.no_grad():
            model.eval()
            for batch_idx, (data, target) in enumerate(loaders['valid']):
                if use_cuda:
                    data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
                output = model(data)
                loss = criterion(output, target)
                valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.item() - valid_loss))

        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch,train_loss,valid_loss))

        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f})'.format(valid_loss_min, valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss

    return model


loaders_scratch = {'train': train_loader,'valid': valid_loader,'test': test_loader}
model_scratch = train(20, loaders_scratch, model_scratch, optimizer_scratch,criterion_scratch, use_cuda, 'model_scratch.pt')
model_scratch.load_state_dict(torch.load('model_scratch.pt'))
# Out:
# Epoch: 1 	Training Loss: 4.852435 	Validation Loss: 4.772727
# Validation loss decreased (inf --> 4.772727)
# Epoch: 2 	Training Loss: 4.695698 	Validation Loss: 4.596937
# Validation loss decreased (4.772727 --> 4.596937)
# Epoch: 3 	Training Loss: 4.562665 	Validation Loss: 4.512728
# Validation loss decreased (4.596937 --> 4.512728)
# Epoch: 4 	Training Loss: 4.515289 	Validation Loss: 4.470449
# Validation loss decreased (4.512728 --> 4.470449)
# Epoch: 5 	Training Loss: 4.456474 	Validation Loss: 4.537040
# Epoch: 6 	Training Loss: 4.410342 	Validation Loss: 4.396074
# Validation loss decreased (4.470449 --> 4.396074)
# Epoch: 7 	Training Loss: 4.394142 	Validation Loss: 4.407510
# Epoch: 8 	Training Loss: 4.326807 	Validation Loss: 4.363823
# Validation loss decreased (4.396074 --> 4.363823)
# Epoch: 9 	Training Loss: 4.273251 	Validation Loss: 4.289093
# Validation loss decreased (4.363823 --> 4.289093)
# Epoch: 10 	Training Loss: 4.231728 	Validation Loss: 4.285416
# Validation loss decreased (4.289093 --> 4.285416)
# Epoch: 11 	Training Loss: 4.185744 	Validation Loss: 4.238802
# Validation loss decreased (4.285416 --> 4.238802)
# Epoch: 12 	Training Loss: 4.146850 	Validation Loss: 4.256540
# Epoch: 13 	Training Loss: 4.102250 	Validation Loss: 4.238186
# Validation loss decreased (4.238802 --> 4.238186)
# Epoch: 14 	Training Loss: 4.061752 	Validation Loss: 4.243286
# Epoch: 15 	Training Loss: 4.020053 	Validation Loss: 4.107360
# Validation loss decreased (4.238186 --> 4.107360)
# Epoch: 16 	Training Loss: 3.956663 	Validation Loss: 4.149590
# Epoch: 17 	Training Loss: 3.947499 	Validation Loss: 4.050176
# Validation loss decreased (4.107360 --> 4.050176)
# Epoch: 18 	Training Loss: 3.907308 	Validation Loss: 4.074217
# Epoch: 19 	Training Loss: 3.848959 	Validation Loss: 4.012397
# Validation loss decreased (4.050176 --> 4.012397)
# Epoch: 20 	Training Loss: 3.792520 	Validation Loss: 4.071567
# <All keys matched successfully>

# %% [markdown]
# ### Testing the model

# %%
def test(loaders, model, criterion, use_cuda):
  test_loss = 0.
  correct = 0.
  total = 0.

  model.eval()
  for batch_idx, (data, target) in enumerate(loaders['test']):
    if use_cuda:
      data, target = data.cuda(), target.cuda()
    output = model(data)
    loss = criterion(output, target)
    test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
    pred = output.data.max(1, keepdim=True)[1]
    correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
    total += data.size(0)

    print('Test Loss: {:.6f}\n'.format(test_loss))
    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (100. * correct / total, correct, total))

test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)
# Out:
# Test Loss: 3.922042
#
#
# Test Accuracy: 10% ( 2/20)
# Test Loss: 3.896894
#
#
# Test Accuracy: 10% ( 4/40)
# Test Loss: 3.907212
#
#
# Test Accuracy: 10% ( 6/60)
# Test Loss: 3.781280
#
#
# Test Accuracy: 12% (10/80)
# Test Loss: 3.825531
#
#
# Test Accuracy: 12% (12/100)
# Test Loss: 3.865957
#
#
# Test Accuracy: 11% (14/120)
# Test Loss: 3.938614
#
#
# Test Accuracy: 10% (14/140)
# Test Loss: 3.958053
#
#
# Test Accuracy:  9% (15/160)
# Test Loss: 3.953030
#
#
# Test Accuracy: 10% (18/180)
# Test Loss: 3.989788
#
#
# Test Accuracy:  9% (19/200)
# Test Loss: 3.986700
#
#
# Test Accuracy:  9% (20/220)
# Test Loss: 3.981966
#
#
# Test Accuracy:  9% (22/240)
# Test Loss: 3.986531
#
#
# Test Accuracy:  9% (24/260)
# Test Loss: 3.978000
#
#
# Test Accuracy:  9% (26/280)
# Test Loss: 3.939102
#
#
# Test Accuracy: 10% (30/300)
# Test Loss: 3.918179
#
#
# Test Accuracy: 10% (32/320)
# Test Loss: 3.926594
#
#
# Test Accuracy: 10% (34/340)
# Test Loss: 3.972341
#
#
# Test Accuracy:  9% (34/360)
# Test Loss: 4.006581
#
#
# Test Accuracy:  8% (34/380)
# Test Loss: 3.998255
#
#
# Test Accuracy:  9% (38/400)
# Test Loss: 4.033213
#
#
# Test Accuracy:  9% (38/420)
# Test Loss: 4.021726
#
#
# Test Accuracy:  8% (39/440)
# Test Loss: 4.025693
#
#
# Test Accuracy:  8% (40/460)
# Test Loss: 4.018628
#
#
# Test Accuracy:  8% (42/480)
# Test Loss: 4.026487
#
#
# Test Accuracy:  8% (42/500)
# Test Loss: 4.013401
#
#
# Test Accuracy:  8% (45/520)
# Test Loss: 4.002051
#
#
# Test Accuracy:  8% (47/540)
# Test Loss: 4.002586
#
#
# Test Accuracy:  8% (47/560)
# Test Loss: 3.997180
#
#
# Test Accuracy:  8% (49/580)
# Test Loss: 3.998218
#
#
# Test Accuracy:  8% (50/600)
# Test Loss: 3.983808
#
#
# Test Accuracy:  8% (54/620)
# Test Loss: 3.989903
#
#
# Test Accuracy:  8% (56/640)
# Test Loss: 3.989913
#
#
# Test Accuracy:  8% (58/660)
# Test Loss: 3.978713
#
#
# Test Accuracy:  9% (63/680)
# Test Loss: 3.976068
#
#
# Test Accuracy:  9% (65/700)
# Test Loss: 3.976184
#
#
# Test Accuracy:  9% (66/720)
# Test Loss: 3.975518
#
#
# Test Accuracy:  9% (69/740)
# Test Loss: 3.980531
#
#
# Test Accuracy:  9% (71/760)
# Test Loss: 3.978558
#
#
# Test Accuracy:  9% (75/780)
# Test Loss: 3.970930
#
#
# Test Accuracy:  9% (78/800)
# Test Loss: 3.969795
#
#
# Test Accuracy: 10% (84/820)
# Test Loss: 3.983105
#
#
# Test Accuracy: 10% (84/836)

# %% [markdown]
# ### Create a CNN to Classify Dog Breeds (using Transfer Learning)

# %%
loaders_transfer = loaders_scratch

# %%
import torchvision.models as models
import torch.nn as nn
model_transfer = models.vgg16(pretrained=True)
if use_cuda:
    model_transfer = model_transfer.cuda()

# %%
for param in model_transfer.features.parameters():
    param.requires_grad = False

# %%
n_inputs = model_transfer.classifier[6].in_features
last_layer = nn.Linear(n_inputs, 133)
model_transfer.classifier[6] = last_layer

if use_cuda:
    model_transfer.cuda()

print(model_transfer.classifier[6].out_features)
# Out:
# 133

# %% [markdown]
# ### Loss Function and Optimizer

# %%
criterion_transfer  = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.classifier.parameters(), lr=0.001)

# %%
model_transfer = train(70, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')
# Out:
# Epoch: 1 	Training Loss: 4.430443 	Validation Loss: 3.704353
# Validation loss decreased (inf --> 3.704353)
# Epoch: 2 	Training Loss: 3.237879 	Validation Loss: 2.496266
# Validation loss decreased (3.704353 --> 2.496266)
# Epoch: 3 	Training Loss: 2.369665 	Validation Loss: 1.892759
# Validation loss decreased (2.496266 --> 1.892759)
# Epoch: 4 	Training Loss: 1.976440 	Validation Loss: 1.731079
# Validation loss decreased (1.892759 --> 1.731079)
# Epoch: 5 	Training Loss: 1.777606 	Validation Loss: 1.536996
# Validation loss decreased (1.731079 --> 1.536996)
# Epoch: 6 	Training Loss: 1.652885 	Validation Loss: 1.458369
# Validation loss decreased (1.536996 --> 1.458369)
# Epoch: 7 	Training Loss: 1.544514 	Validation Loss: 1.399773
# Validation loss decreased (1.458369 --> 1.399773)
# Epoch: 8 	Training Loss: 1.452777 	Validation Loss: 1.306639
# Validation loss decreased (1.399773 --> 1.306639)
# Epoch: 9 	Training Loss: 1.443564 	Validation Loss: 1.326901
# Epoch: 10 	Training Loss: 1.390863 	Validation Loss: 1.255591
# Validation loss decreased (1.306639 --> 1.255591)
# Epoch: 11 	Training Loss: 1.346124 	Validation Loss: 1.193565
# Validation loss decreased (1.255591 --> 1.193565)
# Epoch: 12 	Training Loss: 1.310894 	Validation Loss: 1.233888
# Epoch: 13 	Training Loss: 1.295269 	Validation Loss: 1.211120
# Epoch: 14 	Training Loss: 1.271495 	Validation Loss: 1.167844
# Validation loss decreased (1.193565 --> 1.167844)
# Epoch: 15 	Training Loss: 1.257022 	Validation Loss: 1.164228
# Validation loss decreased (1.167844 --> 1.164228)
# Epoch: 16 	Training Loss: 1.233560 	Validation Loss: 1.156757
# Validation loss decreased (1.164228 --> 1.156757)
# Epoch: 17 	Training Loss: 1.211211 	Validation Loss: 1.103146
# Validation loss decreased (1.156757 --> 1.103146)
# Epoch: 18 	Training Loss: 1.178237 	Validation Loss: 1.093934
# Validation loss decreased (1.103146 --> 1.093934)
# Epoch: 19 	Training Loss: 1.186537 	Validation Loss: 1.153495
# Epoch: 20 	Training Loss: 1.183305 	Validation Loss: 1.179696
# Epoch: 21 	Training Loss: 1.169828 	Validation Loss: 1.156236
# Epoch: 22 	Training Loss: 1.142511 	Validation Loss: 1.107203
# Epoch: 23 	Training Loss: 1.120818 	Validation Loss: 1.095646
# Epoch: 24 	Training Loss: 1.131846 	Validation Loss: 1.134582
# Epoch: 25 	Training Loss: 1.118449 	Validation Loss: 1.154387
# Epoch: 26 	Training Loss: 1.093071 	Validation Loss: 1.108096
# Epoch: 27 	Training Loss: 1.101653 	Validation Loss: 1.048887
# Validation loss decreased (1.093934 --> 1.048887)
# Epoch: 28 	Training Loss: 1.108324 	Validation Loss: 1.112709
# Epoch: 29 	Training Loss: 1.068231 	Validation Loss: 1.131341
# Epoch: 30 	Training Loss: 1.103892 	Validation Loss: 1.101025
# Epoch: 31 	Training Loss: 1.059943 	Validation Loss: 1.016584
# Validation loss decreased (1.048887 --> 1.016584)
# Epoch: 32 	Training Loss: 1.038248 	Validation Loss: 1.060268
# Epoch: 33 	Training Loss: 1.035961 	Validation Loss: 1.074374
# Epoch: 34 	Training Loss: 1.041055 	Validation Loss: 1.067626
# Epoch: 35 	Training Loss: 1.044218 	Validation Loss: 1.124526
# Epoch: 36 	Training Loss: 1.039122 	Validation Loss: 1.012027
# Validation loss decreased (1.016584 --> 1.012027)
# Epoch: 37 	Training Loss: 1.031059 	Validation Loss: 1.106442
# Epoch: 38 	Training Loss: 1.008082 	Validation Loss: 1.009122
# Validation loss decreased (1.012027 --> 1.009122)
# Epoch: 39 	Training Loss: 1.032622 	Validation Loss: 1.133636
# Epoch: 40 	Training Loss: 1.012258 	Validation Loss: 1.148974
# Epoch: 41 	Training Loss: 0.991984 	Validation Loss: 1.117930
# Epoch: 42 	Training Loss: 1.005993 	Validation Loss: 1.032236
# Epoch: 43 	Training Loss: 0.982642 	Validation Loss: 1.001024
# Validation loss decreased (1.009122 --> 1.001024)
# Epoch: 44 	Training Loss: 0.990354 	Validation Loss: 1.086686
# Epoch: 45 	Training Loss: 0.992877 	Validation Loss: 1.069441
# Epoch: 46 	Training Loss: 0.984739 	Validation Loss: 1.061239
# Epoch: 47 	Training Loss: 1.001125 	Validation Loss: 1.055968
# Epoch: 48 	Training Loss: 0.970439 	Validation Loss: 1.102643
# Epoch: 49 	Training Loss: 0.961387 	Validation Loss: 1.030538
# Epoch: 50 	Training Loss: 0.955779 	Validation Loss: 1.139273
# Epoch: 51 	Training Loss: 0.979762 	Validation Loss: 1.002436
# Epoch: 52 	Training Loss: 0.940919 	Validation Loss: 1.028005
# Epoch: 53 	Training Loss: 0.901134 	Validation Loss: 1.054212
# Epoch: 54 	Training Loss: 0.931683 	Validation Loss: 1.006605
# Epoch: 55 	Training Loss: 0.954566 	Validation Loss: 1.045847
# Epoch: 56 	Training Loss: 0.969407 	Validation Loss: 1.076270
# Epoch: 57 	Training Loss: 0.923399 	Validation Loss: 0.970696
# Validation loss decreased (1.001024 --> 0.970696)
# Epoch: 58 	Training Loss: 0.949477 	Validation Loss: 0.990590
# Epoch: 59 	Training Loss: 0.912995 	Validation Loss: 1.046235
# Epoch: 60 	Training Loss: 0.934553 	Validation Loss: 1.038127
# Epoch: 61 	Training Loss: 0.911652 	Validation Loss: 1.051859
# Epoch: 62 	Training Loss: 0.950704 	Validation Loss: 1.092914
# Epoch: 63 	Training Loss: 0.911065 	Validation Loss: 0.995173
# Epoch: 64 	Training Loss: 0.929999 	Validation Loss: 1.031748
# Epoch: 65 	Training Loss: 0.915492 	Validation Loss: 1.044563
# Epoch: 66 	Training Loss: 0.878095 	Validation Loss: 1.061276
# Epoch: 67 	Training Loss: 0.879141 	Validation Loss: 1.137750
# Epoch: 68 	Training Loss: 0.905553 	Validation Loss: 1.047197
# Epoch: 69 	Training Loss: 0.911134 	Validation Loss: 1.007518
# Epoch: 70 	Training Loss: 0.906269 	Validation Loss: 1.027783

# %%
model_transfer.load_state_dict(torch.load('model_transfer.pt'))
# Out:
# <All keys matched successfully>

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)
# Out:
# Test Loss: 1.115923
#
#
# Test Accuracy: 70% (14/20)
# Test Loss: 0.883094
#
#
# Test Accuracy: 75% (30/40)
# Test Loss: 1.015864
#
#
# Test Accuracy: 70% (42/60)
# Test Loss: 1.047483
#
#
# Test Accuracy: 70% (56/80)
# Test Loss: 0.959581
#
#
# Test Accuracy: 72% (72/100)
# Test Loss: 0.918156
#
#
# Test Accuracy: 73% (88/120)
# Test Loss: 0.901637
#
#
# Test Accuracy: 75% (105/140)
# Test Loss: 0.906757
#
#
# Test Accuracy: 73% (118/160)
# Test Loss: 0.914109
#
#
# Test Accuracy: 73% (133/180)
# Test Loss: 1.013928
#
#
# Test Accuracy: 72% (145/200)
# Test Loss: 1.044989
#
#
# Test Accuracy: 70% (155/220)
# Test Loss: 1.115077
#
#
# Test Accuracy: 69% (167/240)
# Test Loss: 1.117678
#
#
# Test Accuracy: 70% (183/260)
# Test Loss: 1.059999
#
#
# Test Accuracy: 71% (201/280)
# Test Loss: 1.043638
#
#
# Test Accuracy: 71% (215/300)
# Test Loss: 1.047680
#
#
# Test Accuracy: 70% (227/320)
# Test Loss: 1.070618
#
#
# Test Accuracy: 71% (242/340)
# Test Loss: 1.099690
#
#
# Test Accuracy: 70% (253/360)
# Test Loss: 1.091042
#
#
# Test Accuracy: 70% (268/380)
# Test Loss: 1.082458
#
#
# Test Accuracy: 70% (283/400)
# Test Loss: 1.098776
#
#
# Test Accuracy: 69% (293/420)
# Test Loss: 1.117546
#
#
# Test Accuracy: 69% (305/440)
# Test Loss: 1.114608
#
#
# Test Accuracy: 69% (321/460)
# Test Loss: 1.112100
#
#
# Test Accuracy: 69% (335/480)
# Test Loss: 1.092868
#
#
# Test Accuracy: 70% (352/500)
# Test Loss: 1.125395
#
#
# Test Accuracy: 69% (363/520)
# Test Loss: 1.099485
#
#
# Test Accuracy: 70% (380/540)
# Test Loss: 1.082176
#
#
# Test Accuracy: 70% (396/560)
# Test Loss: 1.080484
#
#
# Test Accuracy: 70% (409/580)
# Test Loss: 1.090747
#
#
# Test Accuracy: 70% (420/600)
# Test Loss: 1.072437
#
#
# Test Accuracy: 70% (437/620)
# Test Loss: 1.072285
#
#
# Test Accuracy: 70% (451/640)
# Test Loss: 1.082956
#
#
# Test Accuracy: 69% (461/660)
# Test Loss: 1.070639
#
#
# Test Accuracy: 70% (479/680)
# Test Loss: 1.064538
#
#
# Test Accuracy: 70% (493/700)
# Test Loss: 1.061174
#
#
# Test Accuracy: 70% (509/720)
# Test Loss: 1.053156
#
#
# Test Accuracy: 71% (526/740)
# Test Loss: 1.039823
#
#
# Test Accuracy: 71% (543/760)
# Test Loss: 1.031676
#
#
# Test Accuracy: 71% (558/780)
# Test Loss: 1.042346
#
#
# Test Accuracy: 71% (569/800)
# Test Loss: 1.032958
#
#
# Test Accuracy: 71% (587/820)
# Test Loss: 1.034383
#
#
# Test Accuracy: 71% (599/836)

# %%
#Predicting Dog Breed with the Model
class_names = [item[4:].replace("_", " ") for item in train_data.classes]

def predict_breed_transfer(img_path):
    img = Image.open(img_path)
    transform = transforms.Compose([transforms.Resize(255),transforms.CenterCrop(224),transforms.ToTensor()])
    img_tensor = transform(img)
    img_tensor.unsqueeze_(0)

    if use_cuda:
        img_tensor = img_tensor.cuda()

    prediction = model_transfer(img_tensor)

    if use_cuda:
        prediction = prediction.cpu()

    return prediction.data.numpy().argmax()

# %%
def detect(img_path):
    face_detectd = face_detector(img_path)
    dog_detected = dog_detector(img_path)
    pred = predict_breed_transfer(img_path)

    if dog_detected and not face_detectd:
        title = "Hello, dog\nYour predicted breed is...\n{}!".format(class_names[pred])
    elif not dog_detected and face_detectd:
        title = "Hello, human\nYou look like a {}!".format(class_names[pred])
    elif dog_detected and face_detectd:
        title = "Hello human, that's a nice {} you've got there!".format(class_names[pred])
    else:
        title = "Only humans here"

    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.gca().set_title(title)
    plt.show()

# %%
for file in np.array(glob("/gdrive/My Drive/Deep Learning Project/photos/*")):
    detect(file)
